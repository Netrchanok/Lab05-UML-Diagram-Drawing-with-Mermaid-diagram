// %% [markdown]
// # Lab 5.4 การวาด State diagram

// %% [markdown]
// ## แนวทางการศึกษา
//
// ให้ศึกษารูปแบบและวิธีการเขียน mermaid diagram เพื่อวาด state diagram จาก เว็บเพจนี้
//
// https://mermaid.js.org/syntax/stateDiagram.html

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา state diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %%
flowchart LR
    A[Start] --> B{Read A, B, and C}
    B --> C{Sum = A+B+C}
    C --> D{Avg = Sum/3}
    D --> E{Print Sum and Avg}
    E --> F[End]
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="0738950a93ba4acf82455e66840ee1c9"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('0738950a93ba4acf82455e66840ee1c9');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_0738950a93ba4acf82455e66840ee1c9',
//                     `flowchart LR
//     A[Start] --> B{Read A, B, and C}
//     B --> C{Sum = A+B+C}
//     C --> D{Avg = Sum/3}
//     D --> E{Print Sum and Avg}
//     E --> F[End]
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
flowchart LR
    A(Start) --> B{Count = 0, Sum = 0}
    B --> C{Max = 5}
    C --> D{For i = 1 to Max}
    D --> E{Count = Count + 1}
    E --> F{Sum = Sum + Count}
    F --> G{i == Max?}
    G -- Yes --> H{Count = ?, Sum = ?}
    G -- No --> D
    H --> I(End)
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="990b6ee69ddc4b638f7e63552ba83116"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('990b6ee69ddc4b638f7e63552ba83116');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_990b6ee69ddc4b638f7e63552ba83116',
//                     `flowchart LR
//     A(Start) --> B{Count = 0, Sum = 0}
//     B --> C{Max = 5}
//     C --> D{For i = 1 to Max}
//     D --> E{Count = Count + 1}
//     E --> F{Sum = Sum + Count}
//     F --> G{i == Max?}
//     G -- Yes --> H{Count = ?, Sum = ?}
//     G -- No --> D
//     H --> I(End)`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
flowchart LR
    A[Start] --> B{Declare var No1, No2 & Sum}
    B --> C{Read No1 & No2}
    C --> D{Sum = No1 + No2}
    D --> E{Display Sum}
    E --> F[Stop]
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="d6a3a517ad1b4acd9970d621ea3fbbab"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('d6a3a517ad1b4acd9970d621ea3fbbab');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_d6a3a517ad1b4acd9970d621ea3fbbab',
//                     `
// flowchart LR
//     A[Start] --> B{Declare var No1, No2 & Sum}
//     B --> C{Read No1 & No2}
//     C --> D{Sum = No1 + No2}
//     D --> E{Display Sum}
//     E --> F[Stop]`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)
